# %% [markdown]
# # Part 1: Get Reduced Feature List with LASSO

# %%
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = None

import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

ALPHA = 0.5

# %%
# takes about 1 minute to load
df_student = pd.read_csv('../cleaned_data/clean_STU_QQQ.tsv', sep='\t', header=0, index_col=0, dtype={"LANGTEST_PAQ": "object"})
new_nan_values_count = df_student.isnull().sum().sum()
assert new_nan_values_count == 34114739, f"Failed check having {new_nan_values_count} NaNs"

# %%
# drop columns of student weights, date of test
df = df_student.drop(columns=df_student.filter(regex='W_')).drop(columns=["SENWT", "VER_DAT", "CYC", "NatCen", ])
# drop columns of student test scores
df = df[df.columns.drop(list(df.filter(regex='PV')))]

# add the PV1_ colums back
df_student = df.merge(
    df_student.filter(regex='^PV1[A-Z]+$'),
    how="inner",
    left_index=True,
    right_index=True,
)

df_student.shape
# Out:
# (613744, 1094)

# %%
# Drop schools with sample of less than 20 students
col = "CNTSCHID"
print("# schools:", len(df_student[col].unique()))
temp = df_student.groupby(col).count()["CNTSTUID"] >= 20
big_school_samples = temp[temp].index.to_list()
print("# schools with sample of at least 20 students:", len(big_school_samples))
df_student = df_student[df_student[col].isin(big_school_samples)]
df_student.shape
# Out:
# # schools: 21629
# # schools with sample of at least 20 students: 16123
# (557097, 1094)

# %%
# map country ids into country codes
df_student["CNTRYID"] = df_student["CNT"].astype("category").cat.codes
df_student[["CNTRYID", "CNT"]].groupby("CNT").min().sort_values("CNTRYID").to_csv("../map/country_codes.csv")

# %% [markdown]
# ## Split into Train & Val

# %%
from sklearn.model_selection import train_test_split

# create train validation split
X = df_student.drop(columns=["PV1MATH"])
y = df_student['PV1MATH'].values
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.4, random_state=0)

print("Shape of Train Features: {}".format(X_train.shape))
print("Shape of Val Features: {}".format(X_val.shape))
print("Shape of Train Target: {}".format(y_train.shape))
print("Shape of Val Target: {}".format(y_val.shape))
# Out:
# Shape of Train Features: (334258, 1093)
# Shape of Val Features: (222839, 1093)
# Shape of Train Target: (334258,)
# Shape of Val Target: (222839,)

# %%
X_train.select_dtypes("object").head()
# Out:
#             CNT                                   STRATUM SUBNATIO   REGION  \
# 276918   Kosovo           KSV - stratum 08: Large schools   Kosovo   Kosovo
# 435054    Qatar              QAT - stratum 01: Government    Qatar    Qatar
# 348306    Malta            MLT - stratum 01: State school    Malta    Malta
# 1747    Albania  ALB - stratum 05: Urban / South / Public  Albania  Albania
# 208035  Germany             Undisclosed STRATUM - Germany  Germany  Germany
#
#        LANGTEST_QQQ LANGTEST_COG LANGTEST_PAQ   BOOKID  \
# 276918     Albanian     Albanian          NaN   Form 9
# 435054       Arabic       Arabic          NaN  Form 65
# 348306      English      Maltese          NaN   Form 3
# 1747       Albanian     Albanian          NaN  Form 24
# 208035       German       German          NaN  Form 19
#
#                              ST250D06JA                           ST250D07JA  \
# 276918                   Not Applicable                       Not Applicable
# 435054                Qatar :Office-Yes                     Qatar :Cinema-No
# 348306                   Not Applicable                       Not Applicable
# 1747                     Not Applicable                       Not Applicable
# 208035  Germany :A desk to study at-Yes  Germany :A quiet place to study-Yes
#
#                                        ST251D08JA  \
# 276918                             Not Applicable
# 435054            Qatar :Digital video camera-One
# 348306  Malta :Smart TV with Internet access-None
# 1747                               Not Applicable
# 208035                             Not Applicable
#
#                             ST251D09JA  \
# 276918                  Not Applicable
# 435054  Qatar :Video games console-One
# 348306                  Not Applicable
# 1747                    Not Applicable
# 208035                  Not Applicable
#
#                                                ST330D10WA  \
# 276918                                     Not Applicable
# 435054  Qatar : I researched for sponsors to complete ...
# 348306                                     Not Applicable
# 1747                                       Not Applicable
# 208035  Germany : I visited a vocational Information C...
#
#                                         OCOD1  \
# 276918                            No response
# 435054          Education methods specialists
# 348306       Home-based personal care workers
# 1747    Doing housework, bringing up children
# 208035                        Kitchen helpers
#
#                                   OCOD2  \
# 276918                      No response
# 435054     Sales and marketing managers
# 348306                       Plasterers
# 1747    Bricklayers and related workers
# 208035                           Buyers
#
#                                                     OCOD3  \
# 276918                                            Invalid
# 435054  Fitness and recreation instructors and program...
# 348306                                        Journalists
# 1747                                             Dentists
# 208035                                             Buyers
#
#                                                     PROGN  \
# 276918              Kosovo : Upper Secondary - Vocational
# 435054                 Qatar : Upper Secondary Government
# 348306                Malta : Secondary education (upper)
# 1747                  Albania : Upper secondary education
# 208035  Germany : Lower secondary, access to upper sec...
#
#                        COBN_S                 COBN_M                 COBN_F  \
# 276918                Missing          I don’t know.                Missing
# 435054  Another country (QAT)  Another country (QAT)  Another country (QAT)
# 348306                  Malta                  Malta                  Malta
# 1747                  Albania                Albania                Albania
# 208035                Germany  Another country (DEU)                Germany
#
#            LANGN
# 276918  Albanian
# 435054    Arabic
# 348306   Maltese
# 1747    Albanian
# 208035    German

# %%
# drop object features
X_train = X_train.select_dtypes(exclude="object")
X_val = X_val.select_dtypes(exclude="object")

# drop PV features
X_train = X_train.drop(columns=X_train.filter(regex="PV.*").columns)
X_val = X_val.drop(columns=X_val.filter(regex="PV.*").columns)

print("Shape of Train Features: {}".format(X_train.shape))
print("Shape of Val Features: {}".format(X_val.shape))
print("Shape of Train Target: {}".format(y_train.shape))
print("Shape of Val Target: {}".format(y_val.shape))
# Out:
# Shape of Train Features: (334258, 1062)
# Shape of Val Features: (222839, 1062)
# Shape of Train Target: (334258,)
# Shape of Val Target: (222839,)

# %%
X_train.to_csv("../cleaned_data/X_train.csv")
np.savetxt("../cleaned_data/y_train.csv", y_train, delimiter=",")
X_val.to_csv("../cleaned_data/X_val.csv")
np.savetxt("../cleaned_data/y_val.csv", y_val, delimiter=",")

# %%
(X_train.std() == 0).sum()
# Out:
# np.int64(0)

# %%
X_train.info(verbose = True, show_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 334258 entries, 276918 to 343045
# Data columns (total 1062 columns):
#  #     Column       Non-Null Count   Dtype
# ---    ------       --------------   -----
#  0     CNTRYID      334258 non-null  int8
#  1     CNTSCHID     334258 non-null  float64
#  2     CNTSTUID     334258 non-null  float64
#  3     OECD         334258 non-null  int64
#  4     ADMINMODE    334258 non-null  int64
#  5     Option_CT    334258 non-null  int64
#  6     Option_FL    334258 non-null  int64
#  7     Option_ICTQ  334258 non-null  int64
#  8     Option_WBQ   334258 non-null  int64
#  9     Option_PQ    334258 non-null  int64
#  10    Option_TQ    334258 non-null  int64
#  11    Option_UH    334258 non-null  int64
#  12    ST001D01T    334258 non-null  int64
#  13    ST003D02T    334258 non-null  int64
#  14    ST003D03T    327198 non-null  float64
#  15    ST004D01T    334258 non-null  int64
#  16    ST250Q01JA   334258 non-null  int64
#  17    ST250Q02JA   334258 non-null  int64
#  18    ST250Q03JA   334258 non-null  int64
#  19    ST250Q04JA   334258 non-null  int64
#  20    ST250Q05JA   334258 non-null  int64
#  21    ST251Q01JA   334258 non-null  int64
#  22    ST251Q02JA   334258 non-null  int64
#  23    ST251Q03JA   334258 non-null  int64
#  24    ST251Q04JA   334258 non-null  int64
#  25    ST251Q06JA   334258 non-null  int64
#  26    ST251Q07JA   334258 non-null  int64
#  27    ST253Q01JA   334258 non-null  int64
#  28    ST254Q01JA   334258 non-null  int64
#  29    ST254Q02JA   334258 non-null  int64
#  30    ST254Q03JA   334258 non-null  int64
#  31    ST254Q04JA   334258 non-null  int64
#  32    ST254Q05JA   334258 non-null  int64
#  33    ST254Q06JA   334258 non-null  int64
#  34    ST255Q01JA   334258 non-null  int64
#  35    ST256Q01JA   334258 non-null  int64
#  36    ST256Q02JA   334258 non-null  int64
#  37    ST256Q03JA   334258 non-null  int64
#  38    ST256Q06JA   334258 non-null  int64
#  39    ST256Q07JA   334258 non-null  int64
#  40    ST256Q08JA   334258 non-null  int64
#  41    ST256Q09JA   334258 non-null  int64
#  42    ST256Q10JA   334258 non-null  int64
#  43    ST230Q01JA   334258 non-null  int64
#  44    ST005Q01JA   334258 non-null  int64
#  45    ST006Q01JA   334258 non-null  int64
#  46    ST006Q02JA   334258 non-null  int64
#  47    ST006Q03JA   334258 non-null  int64
#  48    ST006Q04JA   334258 non-null  int64
#  49    ST006Q05JA   334258 non-null  int64
#  50    ST007Q01JA   334258 non-null  int64
#  51    ST008Q01JA   334258 non-null  int64
#  52    ST008Q02JA   334258 non-null  int64
#  53    ST008Q03JA   334258 non-null  int64
#  54    ST008Q04JA   334258 non-null  int64
#  55    ST008Q05JA   334258 non-null  int64
#  56    ST258Q01JA   334258 non-null  int64
#  57    ST259Q01JA   266574 non-null  float64
#  58    ST259Q02JA   263254 non-null  float64
#  59    ST019AQ01T   334258 non-null  int64
#  60    ST019BQ01T   334258 non-null  int64
#  61    ST019CQ01T   334258 non-null  int64
#  62    ST021Q01TA   334258 non-null  int64
#  63    ST022Q01TA   334258 non-null  int64
#  64    ST226Q01JA   334258 non-null  int64
#  65    ST125Q01NA   334258 non-null  int64
#  66    ST126Q01TA   334258 non-null  int64
#  67    ST127Q01TA   334258 non-null  int64
#  68    ST127Q02TA   334258 non-null  int64
#  69    ST127Q03TA   334258 non-null  int64
#  70    ST260Q01JA   334258 non-null  int64
#  597   FL171Q08JA   334258 non-null  int64
#  598   FL171Q09JA   334258 non-null  int64
#  599   FL171Q10JA   334258 non-null  int64
#  600   FL171Q11JA   334258 non-null  int64
#  601   FL171Q12JA   334258 non-null  int64
#  602   FL169Q01HA   334258 non-null  int64
#  603   FL169Q05JA   334258 non-null  int64
#  604   FL169Q02HA   334258 non-null  int64
#  605   FL169Q06JA   334258 non-null  int64
#  606   FL169Q07JA   334258 non-null  int64
#  607   FL169Q03HA   334258 non-null  int64
#  608   FL169Q04HA   334258 non-null  int64
#  609   FL169Q08JA   334258 non-null  int64
#  610   FL169Q10JA   334258 non-null  int64
#  611   FL169Q11JA   334258 non-null  int64
#  612   FL172Q01JA   334258 non-null  int64
#  613   FL172Q03JA   334258 non-null  int64
#  614   FL172Q05JA   334258 non-null  int64
#  615   FL172Q06JA   334258 non-null  int64
#  616   IC170Q01JA   334258 non-null  int64
#  617   IC170Q02JA   334258 non-null  int64
#  618   IC170Q03JA   334258 non-null  int64
#  619   IC170Q04JA   334258 non-null  int64
#  620   IC170Q05JA   334258 non-null  int64
#  621   IC170Q06JA   334258 non-null  int64
#  622   IC170Q07JA   334258 non-null  int64
#  623   IC171Q01JA   334258 non-null  int64
#  624   IC171Q02JA   334258 non-null  int64
#  625   IC171Q03JA   334258 non-null  int64
#  626   IC171Q04JA   334258 non-null  int64
#  627   IC171Q05JA   334258 non-null  int64
#  628   IC171Q06JA   334258 non-null  int64
#  629   IC172Q01JA   334258 non-null  int64
#  630   IC172Q02JA   334258 non-null  int64
#  631   IC172Q03JA   334258 non-null  int64
#  632   IC172Q04JA   334258 non-null  int64
#  633   IC172Q05JA   334258 non-null  int64
#  634   IC172Q06JA   334258 non-null  int64
#  635   IC172Q07JA   334258 non-null  int64
#  636   IC172Q08JA   334258 non-null  int64
#  637   IC172Q09JA   334258 non-null  int64
#  638   IC173Q01JA   334258 non-null  int64
#  639   IC173Q02JA   334258 non-null  int64
#  640   IC173Q03JA   334258 non-null  int64
#  641   IC173Q04JA   334258 non-null  int64
#  642   IC174Q01JA   334258 non-null  int64
#  643   IC174Q02JA   334258 non-null  int64
#  644   IC174Q03JA   334258 non-null  int64
#  645   IC174Q04JA   334258 non-null  int64
#  646   IC174Q05JA   334258 non-null  int64
#  647   IC174Q06JA   334258 non-null  int64
#  648   IC174Q07JA   334258 non-null  int64
#  649   IC174Q08JA   334258 non-null  int64
#  650   IC174Q09JA   334258 non-null  int64
#  651   IC174Q10JA   334258 non-null  int64
#  652   IC175Q01JA   334258 non-null  int64
#  653   IC175Q02JA   334258 non-null  int64
#  654   IC175Q03JA   334258 non-null  int64
#  655   IC175Q05JA   334258 non-null  int64
#  656   IC176Q01JA   334258 non-null  int64
#  657   IC176Q02JA   334258 non-null  int64
#  658   IC176Q03JA   334258 non-null  int64
#  659   IC176Q04JA   334258 non-null  int64
#  660   IC176Q05JA   334258 non-null  int64
#  661   IC176Q06JA   334258 non-null  int64
#  662   IC176Q07JA   334258 non-null  int64
#  663   IC176Q08JA   334258 non-null  int64
#  664   IC184Q01JA   334258 non-null  int64
#  665   IC184Q02JA   334258 non-null  int64
#  666   IC184Q03JA   334258 non-null  int64
#  667   IC184Q04JA   334258 non-null  int64
#  668   IC177Q01JA   334258 non-null  int64
#  669   IC177Q02JA   334258 non-null  int64
#  670   IC177Q03JA   334258 non-null  int64
#  671   IC177Q04JA   334258 non-null  int64
#  672   IC177Q05JA   334258 non-null  int64
#  673   IC177Q06JA   334258 non-null  int64
#  674   IC177Q07JA   334258 non-null  int64
#  675   IC178Q01JA   334258 non-null  int64
#  676   IC178Q02JA   334258 non-null  int64
#  677   IC178Q03JA   334258 non-null  int64
#  678   IC178Q04JA   334258 non-null  int64
#  679   IC178Q05JA   334258 non-null  int64
#  680   IC178Q06JA   334258 non-null  int64
#  681   IC178Q07JA   334258 non-null  int64
#  682   IC179Q01JA   334258 non-null  int64
#  683   IC179Q02JA   334258 non-null  int64
#  684   IC179Q03JA   334258 non-null  int64
#  685   IC179Q04JA   334258 non-null  int64
#  686   IC179Q05JA   334258 non-null  int64
#  687   IC179Q06JA   334258 non-null  int64
#  688   IC180Q01JA   334258 non-null  int64
#  689   IC180Q02JA   334258 non-null  int64
#  690   IC180Q03JA   334258 non-null  int64
#  691   IC180Q04JA   334258 non-null  int64
#  692   IC180Q05JA   334258 non-null  int64
#  693   IC180Q06JA   334258 non-null  int64
#  694   IC180Q07JA   334258 non-null  int64
#  695   IC180Q08JA   334258 non-null  int64
#  696   IC181Q01JA   334258 non-null  int64
#  697   IC181Q02JA   334258 non-null  int64
#  698   IC181Q03JA   334258 non-null  int64
#  699   IC181Q04JA   334258 non-null  int64
#  700   IC182Q01JA   334258 non-null  int64
#  701   IC182Q02JA   334258 non-null  int64
#  702   IC182Q03JA   334258 non-null  int64
#  703   IC183Q01JA   334258 non-null  int64
#  704   IC183Q02JA   334258 non-null  int64
#  705   IC183Q03JA   334258 non-null  int64
#  706   IC183Q04JA   334258 non-null  int64
#  707   IC183Q05JA   334258 non-null  int64
#  708   IC183Q07JA   334258 non-null  int64
#  709   IC183Q08JA   334258 non-null  int64
#  710   IC183Q09JA   334258 non-null  int64
#  711   IC183Q10JA   334258 non-null  int64
#  712   IC183Q12JA   334258 non-null  int64
#  713   IC183Q13JA   334258 non-null  int64
#  714   IC183Q14JA   334258 non-null  int64
#  715   IC183Q15JA   334258 non-null  int64
#  716   IC183Q16JA   334258 non-null  int64
#  717   WB150Q01HA   334258 non-null  int64
#  718   WB151Q01HA   50229 non-null   float64
#  719   WB152Q01HA   51296 non-null   float64
#  720   WB153Q01HA   334258 non-null  int64
#  721   WB153Q02HA   334258 non-null  int64
#  722   WB153Q03HA   334258 non-null  int64
#  723   WB153Q04HA   334258 non-null  int64
#  724   WB153Q05HA   334258 non-null  int64
#  725   WB154Q01HA   334258 non-null  int64
#  726   WB154Q02HA   334258 non-null  int64
#  727   WB154Q03HA   334258 non-null  int64
#  728   WB154Q04HA   334258 non-null  int64
#  729   WB154Q05HA   334258 non-null  int64
#  730   WB154Q06HA   334258 non-null  int64
#  731   WB154Q07HA   334258 non-null  int64
#  732   WB154Q08HA   334258 non-null  int64
#  733   WB154Q09HA   334258 non-null  int64
#  734   WB155Q01HA   334258 non-null  int64
#  735   WB155Q02HA   334258 non-null  int64
#  736   WB155Q03HA   334258 non-null  int64
#  737   WB155Q04HA   334258 non-null  int64
#  738   WB155Q05HA   334258 non-null  int64
#  739   WB155Q06HA   334258 non-null  int64
#  740   WB155Q07HA   334258 non-null  int64
#  741   WB155Q08HA   334258 non-null  int64
#  742   WB155Q09HA   334258 non-null  int64
#  743   WB155Q10HA   334258 non-null  int64
#  744   WB156Q01HA   64158 non-null   float64
#  745   WB158Q01HA   334258 non-null  int64
#  746   WB160Q01HA   334258 non-null  int64
#  747   WB161Q01HA   334258 non-null  int64
#  748   WB162Q01HA   334258 non-null  int64
#  749   WB162Q02HA   334258 non-null  int64
#  750   WB162Q03HA   334258 non-null  int64
#  751   WB162Q04HA   334258 non-null  int64
#  752   WB162Q05HA   334258 non-null  int64
#  753   WB162Q06HA   334258 non-null  int64
#  754   WB162Q07HA   334258 non-null  int64
#  755   WB162Q08HA   334258 non-null  int64
#  756   WB162Q09HA   334258 non-null  int64
#  757   WB163Q01HA   334258 non-null  int64
#  758   WB163Q02HA   334258 non-null  int64
#  759   WB163Q03HA   334258 non-null  int64
#  760   WB163Q04HA   334258 non-null  int64
#  761   WB163Q05HA   334258 non-null  int64
#  762   WB163Q06HA   334258 non-null  int64
#  763   WB163Q07HA   334258 non-null  int64
#  764   WB163Q08HA   334258 non-null  int64
#  765   WB164Q01HA   334258 non-null  int64
#  766   WB165Q01HA   334258 non-null  int64
#  767   WB166Q01HA   334258 non-null  int64
#  768   WB166Q02HA   334258 non-null  int64
#  769   WB166Q03HA   334258 non-null  int64
#  770   WB166Q04HA   334258 non-null  int64
#  771   WB167Q01HA   334258 non-null  int64
#  772   WB168Q01HA   334258 non-null  int64
#  773   WB168Q02HA   334258 non-null  int64
#  774   WB168Q03HA   334258 non-null  int64
#  775   WB168Q04HA   334258 non-null  int64
#  776   WB171Q01HA   334258 non-null  int64
#  777   WB171Q02HA   334258 non-null  int64
#  778   WB171Q03HA   334258 non-null  int64
#  779   WB171Q04HA   334258 non-null  int64
#  780   WB172Q01HA   334258 non-null  int64
#  781   WB173Q01HA   334258 non-null  int64
#  782   WB173Q02HA   334258 non-null  int64
#  783   WB173Q03HA   334258 non-null  int64
#  784   WB173Q04HA   334258 non-null  int64
#  785   WB176Q01HA   334258 non-null  int64
#  786   WB177Q01HA   334258 non-null  int64
#  787   WB177Q02HA   334258 non-null  int64
#  788   WB177Q03HA   334258 non-null  int64
#  789   WB177Q04HA   334258 non-null  int64
#  790   WB032Q01NA   334258 non-null  int64
#  791   WB032Q02NA   334258 non-null  int64
#  792   WB031Q01NA   334258 non-null  int64
#  793   WB178Q01HA   334258 non-null  int64
#  794   WB178Q02HA   334258 non-null  int64
#  795   WB178Q03HA   334258 non-null  int64
#  796   WB178Q04HA   334258 non-null  int64
#  797   WB178Q05HA   334258 non-null  int64
#  798   WB178Q06HA   334258 non-null  int64
#  799   WB178Q07HA   334258 non-null  int64
#  800   PA001Q01TA   334258 non-null  int64
#  801   PA001Q02TA   334258 non-null  int64
#  802   PA001Q03TA   334258 non-null  int64
#  803   PA003Q01TA   334258 non-null  int64
#  804   PA003Q02TA   334258 non-null  int64
#  805   PA003Q03TA   334258 non-null  int64
#  806   PA003Q05IA   334258 non-null  int64
#  807   PA003Q18WA   334258 non-null  int64
#  808   PA003Q19WA   334258 non-null  int64
#  809   PA003Q20WA   334258 non-null  int64
#  810   PA003Q11JA   334258 non-null  int64
#  811   PA003Q12JA   334258 non-null  int64
#  812   PA003Q13JA   334258 non-null  int64
#  813   PA003Q14JA   334258 non-null  int64
#  814   PA003Q15JA   334258 non-null  int64
#  815   PA003Q16JA   334258 non-null  int64
#  816   PA003Q17JA   334258 non-null  int64
#  817   PA196Q01WA   334258 non-null  int64
#  818   PA196Q02WA   334258 non-null  int64
#  819   PA196Q03WA   334258 non-null  int64
#  820   PA196Q04WA   334258 non-null  int64
#  821   PA197Q01WA   334258 non-null  int64
#  822   PA197Q02WA   334258 non-null  int64
#  823   PA197Q03WA   334258 non-null  int64
#  824   PA197Q04WA   334258 non-null  int64
#  825   PA197Q05WA   334258 non-null  int64
#  826   PA008Q01TA   334258 non-null  int64
#  827   PA008Q02TA   334258 non-null  int64
#  828   PA008Q03TA   334258 non-null  int64
#  829   PA008Q04TA   334258 non-null  int64
#  830   PA008Q05TA   334258 non-null  int64
#  831   PA008Q06NA   334258 non-null  int64
#  832   PA008Q07NA   334258 non-null  int64
#  833   PA008Q08NA   334258 non-null  int64
#  834   PA008Q09NA   334258 non-null  int64
#  835   PA008Q10NA   334258 non-null  int64
#  836   PA009Q01NA   334258 non-null  int64
#  837   PA009Q02NA   334258 non-null  int64
#  838   PA009Q03NA   334258 non-null  int64
#  839   PA009Q04NA   334258 non-null  int64
#  840   PA009Q05NA   334258 non-null  int64
#  841   PA009Q06NA   334258 non-null  int64
#  842   PA009Q07NA   334258 non-null  int64
#  843   PA009Q08NA   334258 non-null  int64
#  844   PA009Q09NA   334258 non-null  int64
#  845   PA009Q10NA   334258 non-null  int64
#  846   PA009Q11NA   334258 non-null  int64
#  847   PA007Q01TA   334258 non-null  int64
#  848   PA007Q02TA   334258 non-null  int64
#  849   PA007Q03TA   334258 non-null  int64
#  850   PA007Q04TA   334258 non-null  int64
#  851   PA007Q05TA   334258 non-null  int64
#  852   PA007Q06TA   334258 non-null  int64
#  853   PA007Q07TA   334258 non-null  int64
#  854   PA007Q09NA   334258 non-null  int64
#  855   PA007Q11NA   334258 non-null  int64
#  856   PA007Q12NA   334258 non-null  int64
#  857   PA007Q13NA   334258 non-null  int64
#  858   PA007Q14NA   334258 non-null  int64
#  925   PA188Q02JA   334258 non-null  int64
#  926   PA188Q03JA   334258 non-null  int64
#  927   PA188Q04JA   334258 non-null  int64
#  928   PA188Q05JA   334258 non-null  int64
#  929   PA188Q06JA   334258 non-null  int64
#  930   PA188Q08JA   334258 non-null  int64
#  931   PA188Q09JA   334258 non-null  int64
#  932   PA188Q10JA   334258 non-null  int64
#  933   PA189Q01JA   334258 non-null  int64
#  934   PA189Q02JA   334258 non-null  int64
#  935   PA189Q03JA   334258 non-null  int64
#  936   PA189Q04JA   334258 non-null  int64
#  937   PA189Q05JA   334258 non-null  int64
#  938   PA189Q06JA   334258 non-null  int64
#  939   PA189Q09JA   334258 non-null  int64
#  940   PA189Q10JA   334258 non-null  int64
#  941   PA194Q01JA   334258 non-null  int64
#  942   PA195Q01JA   334258 non-null  int64
#  943   PA041Q01TA   334258 non-null  int64
#  944   PA042Q01TA   334258 non-null  int64
#  945   EFFORT1      284698 non-null  float64
#  946   EFFORT2      281555 non-null  float64
#  947   AGE          334258 non-null  float64
#  948   GRADE        321193 non-null  float64
#  949   ISCEDP       334258 non-null  int64
#  950   IMMIG        334258 non-null  int64
#  951   REPEAT       334258 non-null  int64
#  952   MISSSC       334258 non-null  int64
#  953   SKIPPING     334258 non-null  int64
#  954   TARDYSD      334258 non-null  int64
#  955   EXERPRAC     334258 non-null  int64
#  956   STUDYHMW     334258 non-null  int64
#  957   WORKPAY      334258 non-null  int64
#  958   WORKHOME     334258 non-null  int64
#  959   EXPECEDU     334258 non-null  int64
#  960   MATHPREF     334258 non-null  int64
#  961   MATHEASE     334258 non-null  int64
#  962   MATHMOT      334258 non-null  int64
#  963   DURECEC      334258 non-null  int64
#  964   BSMJ         203860 non-null  float64
#  965   SISCO        334258 non-null  int64
#  966   RELATST      267746 non-null  float64
#  967   BELONG       306794 non-null  float64
#  968   BULLIED      310314 non-null  float64
#  969   FEELSAFE     282964 non-null  float64
#  970   SCHRISK      259042 non-null  float64
#  971   PERSEVAGR    187474 non-null  float64
#  972   CURIOAGR     273914 non-null  float64
#  973   COOPAGR      151868 non-null  float64
#  974   EMPATAGR     174234 non-null  float64
#  975   ASSERAGR     167725 non-null  float64
#  976   STRESAGR     158153 non-null  float64
#  977   EMOCOAGR     233249 non-null  float64
#  978   GROSAGR      275451 non-null  float64
#  979   INFOSEEK     221514 non-null  float64
#  980   FAMSUP       259561 non-null  float64
#  981   DISCLIM      297165 non-null  float64
#  982   TEACHSUP     283380 non-null  float64
#  983   COGACRCO     287030 non-null  float64
#  984   COGACMCO     273249 non-null  float64
#  985   EXPOFA       284059 non-null  float64
#  986   EXPO21ST     280124 non-null  float64
#  987   MATHEFF      257193 non-null  float64
#  988   MATHEF21     267990 non-null  float64
#  989   FAMCON       178944 non-null  float64
#  990   ANXMAT       259946 non-null  float64
#  991   MATHPERS     276326 non-null  float64
#  992   CREATEFF     254599 non-null  float64
#  993   CREATSCH     253913 non-null  float64
#  994   CREATFAM     251099 non-null  float64
#  995   CREATAS      229724 non-null  float64
#  996   CREATOOS     219433 non-null  float64
#  997   CREATOP      253685 non-null  float64
#  998   OPENART      251249 non-null  float64
#  999   IMAGINE      183476 non-null  float64
#  1000  SCHSUST      205055 non-null  float64
#  1001  LEARRES      176219 non-null  float64
#  1002  PROBSELF     199034 non-null  float64
#  1003  FAMSUPSL     196221 non-null  float64
#  1004  FEELLAH      127674 non-null  float64
#  1005  SDLEFF       192505 non-null  float64
#  1006  MISCED       334258 non-null  int64
#  1007  FISCED       334258 non-null  int64
#  1008  HISCED       334258 non-null  int64
#  1009  PAREDINT     318539 non-null  float64
#  1010  BMMJ1        275267 non-null  float64
#  1011  BFMJ2        257213 non-null  float64
#  1012  HISEI        295436 non-null  float64
#  1013  ICTRES       189689 non-null  float64
#  1014  HOMEPOS      325962 non-null  float64
#  1015  ESCS         320735 non-null  float64
#  1016  FCFMLRTY     334258 non-null  int64
#  1017  FLSCHOOL     88365 non-null   float64
#  1018  FLMULTSB     68077 non-null   float64
#  1019  FLFAMILY     87440 non-null   float64
#  1020  ACCESSFP     86369 non-null   float64
#  1021  FLCONFIN     85194 non-null   float64
#  1022  FLCONICT     84342 non-null   float64
#  1023  ACCESSFA     84887 non-null   float64
#  1024  ATTCONFM     83873 non-null   float64
#  1025  FRINFLFM     84598 non-null   float64
#  1026  ICTSCH       189095 non-null  float64
#  1027  ICTAVSCH     334258 non-null  int64
#  1028  ICTHOME      180901 non-null  float64
#  1029  ICTAVHOM     334258 non-null  int64
#  1030  ICTQUAL      185202 non-null  float64
#  1031  ICTSUBJ      177252 non-null  float64
#  1032  ICTENQ       175984 non-null  float64
#  1033  ICTFEED      175618 non-null  float64
#  1034  ICTOUT       174699 non-null  float64
#  1035  ICTWKDY      177176 non-null  float64
#  1036  ICTWKEND     161682 non-null  float64
#  1037  ICTREG       178023 non-null  float64
#  1038  ICTINFO      174245 non-null  float64
#  1039  ICTDISTR     144816 non-null  float64
#  1040  ICTEFFIC     170405 non-null  float64
#  1041  STUBMI       49934 non-null   float64
#  1042  BODYIMA      56147 non-null   float64
#  1043  SOCONPA      59946 non-null   float64
#  1044  LIFESAT      58466 non-null   float64
#  1045  PSYCHSYM     61750 non-null   float64
#  1046  SOCCON       59972 non-null   float64
#  1047  EXPWB        47291 non-null   float64
#  1048  CURSUPP      33133 non-null   float64
#  1049  PQMIMP       49529 non-null   float64
#  1050  PQMCAR       48275 non-null   float64
#  1051  PARINVOL     49431 non-null   float64
#  1052  PQSCHOOL     49566 non-null   float64
#  1053  PASCHPOL     49316 non-null   float64
#  1054  ATTIMMP      43749 non-null   float64
#  1055  PAREXPT      334258 non-null  int64
#  1056  CREATHME     49377 non-null   float64
#  1057  CREATACT     38695 non-null   float64
#  1058  CREATOPN     49184 non-null   float64
#  1059  CREATOR      49331 non-null   float64
#  1060  UNIT         334258 non-null  int64
#  1061  WVARSTRR     334258 non-null  float64
# dtypes: float64(113), int64(948), int8(1)
# memory usage: 2.6 GB

# %% [markdown]
# ## Data Processing

# %%
#  handle NaNs
from sklearn.impute import SimpleImputer

# Don't know if this is legit, but want LASSO to put less weight on columns with missing features
imputer = SimpleImputer(missing_values=np.nan, add_indicator=False, strategy="constant", fill_value=-1)
imputer.fit(X_train)

X_train = imputer.transform(X_train)
X_val = imputer.transform(X_val)

print("Shape of Train Features: {}".format(X_train.shape))
print("Shape of Val Features: {}".format(X_val.shape))
print("Shape of Train Target: {}".format(y_train.shape))
print("Shape of Val Target: {}".format(y_val.shape))
# Out:
# Shape of Train Features: (334258, 1062)
# Shape of Val Features: (222839, 1062)
# Shape of Train Target: (334258,)
# Shape of Val Target: (222839,)

# %%
# scale data to 0 mean 1 var
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_val = scaler.transform(X_val)

print("Shape of Train Features: {}".format(X_train.shape))
print("Shape of Val Features: {}".format(X_val.shape))
print("Shape of Train Target: {}".format(y_train.shape))
print("Shape of Val Target: {}".format(y_val.shape))
# Out:
# Shape of Train Features: (334258, 1062)
# Shape of Val Features: (222839, 1062)
# Shape of Train Target: (334258,)
# Shape of Val Target: (222839,)

# %%
X_train
# Out:
# array([[-0.06625226, -0.23656993, -0.23530156, ..., -0.28616594,
#         -0.98654175, -0.32061971],
#        [ 0.80265192,  0.75187211,  0.75635198, ..., -0.28616594,
#         -0.98654175,  0.24560801],
#        [ 0.14062969,  0.10603396,  0.10838913, ..., -0.28616594,
#         -0.98654175, -0.36417569],
#        ...,
#        [-1.0592856 , -0.99267009, -0.99397977, ...,  1.14325211,
#         -0.98654175,  0.81183574],
#        [ 1.09228665,  1.03147458,  1.03704614, ..., -0.28616594,
#         -0.98654175, -1.67085507],
#        [ 0.0992533 ,  0.05878292,  0.06109283, ..., -0.28616594,
#          0.88387153,  0.81183574]])

# %%
X_train.shape
# Out:
# (334258, 1062)

# %%
from sklearn.linear_model import Lasso

# Create a Lasso Regression model
alpha = ALPHA # Regularization strength (adjust as needed)
lasso_reg = Lasso(alpha=alpha)

# Fit the model to the training data
lasso_reg.fit(X_train, y_train)

# Print the coefficients and intercept
print(f"Coefficient: {lasso_reg.coef_}")
print(f"Intercept: {lasso_reg.intercept_}")
# Out:
# Coefficient: [ 1.57005143  0.          0.         ... -0.         -0.
#  -0.        ]
# Intercept: 443.4480492703243

# %%
coefs = pd.DataFrame(
    lasso_reg.coef_,
    columns=["Coefficients importance"],
    index=list(imputer.get_feature_names_out()),
)
coefs.to_csv(f"LASSO_coef_alpha_{ALPHA}_NO_PV.csv")

# %%
X_train = X_train[:, (coefs["Coefficients importance"] != 0).values]
X_val = X_val[:, (coefs["Coefficients importance"] != 0).values]

print("Shape of Reduced Train Features: {}".format(X_train.shape))
print("Shape of Reduced Val Features: {}".format(X_val.shape))
print("Shape of Reduced Train Target: {}".format(y_train.shape))
print("Shape of Reduced Val Target: {}".format(y_val.shape))
# Out:
# Shape of Reduced Train Features: (334258, 384)
# Shape of Reduced Val Features: (222839, 384)
# Shape of Reduced Train Target: (334258,)
# Shape of Reduced Val Target: (222839,)
